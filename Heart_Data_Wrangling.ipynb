# %%
import pandas as pd

# %%
col_names = ['age', 
             'sex', 
             'chest_pain', 
             'resting_bp', 
             'cholesterol', 
             'high_blood_sugar', 
             'resting_ecg', 
             'max_heart_rate', 
             'angina', 
             'oldpeak', 
             'ST_slope', 
             'major_vessels', 
             'thalassemia', 
             'heart_disease']

# %%
raw_heart = pd.read_table("heart.dat", sep = " ", header = None, names = col_names)

# %%
raw_heart.head()
# Out:
#     age  sex  chest_pain  resting_bp  cholesterol  high_blood_sugar  \
# 0  70.0  1.0         4.0       130.0        322.0               0.0
# 1  67.0  0.0         3.0       115.0        564.0               0.0
# 2  57.0  1.0         2.0       124.0        261.0               0.0
# 3  64.0  1.0         4.0       128.0        263.0               0.0
# 4  74.0  0.0         2.0       120.0        269.0               0.0
#
#    resting_ecg  max_heart_rate  angina  oldpeak  ST_slope  major_vessels  \
# 0          2.0           109.0     0.0      2.4       2.0            3.0
# 1          2.0           160.0     0.0      1.6       2.0            0.0
# 2          0.0           141.0     0.0      0.3       1.0            0.0
# 3          0.0           105.0     1.0      0.2       2.0            1.0
# 4          2.0           121.0     1.0      0.2       1.0            1.0
#
#    thalassemia  heart_disease
# 0          3.0              2
# 1          7.0              1
# 2          7.0              2
# 3          7.0              1
# 4          3.0              1

# %%
#create a copy of the raw_data
heart = raw_heart

heart.sex.replace({0.0: "Female", 1.0: "Male"}, inplace = True)
heart.chest_pain.replace({1.0: "Typical", 2.0: "Atypical", 3.0: "Non_Anginal", 4.0: "Asymptomatic"}, inplace = True)
heart.high_blood_sugar.replace({0.0: "False", 1.0: "True"}, inplace = True)
heart.resting_ecg.replace({0.0: "Normal", 1.0: "Abnormal", 2.0: "LV_Growth"}, inplace = True)
heart.angina.replace({0.0: "False", 1.0: "True"}, inplace = True)
heart.ST_slope.replace({1.0: "Downsloping", 2.0: "Slope", 3.0: "Upsloping"}, inplace = True)
heart.thalassemia.replace({0.0: "Normal", 3.0: "Fixed_Defect", 7.0: "Reversable_Defect"}, inplace = True)
heart.heart_disease.replace({1.0: "Absent", 2.0: "Present"}, inplace = True)

# %%
heart.head()
# Out:
#     age     sex    chest_pain  resting_bp  cholesterol high_blood_sugar  \
# 0  70.0    Male  Asymptomatic       130.0        322.0            False
# 1  67.0  Female   Non_Anginal       115.0        564.0            False
# 2  57.0    Male      Atypical       124.0        261.0            False
# 3  64.0    Male  Asymptomatic       128.0        263.0            False
# 4  74.0  Female      Atypical       120.0        269.0            False
#
#   resting_ecg  max_heart_rate angina  oldpeak     ST_slope  major_vessels  \
# 0   LV_Growth           109.0  False      2.4        Slope            3.0
# 1   LV_Growth           160.0  False      1.6        Slope            0.0
# 2      Normal           141.0  False      0.3  Downsloping            0.0
# 3      Normal           105.0   True      0.2        Slope            1.0
# 4   LV_Growth           121.0   True      0.2  Downsloping            1.0
#
#          thalassemia heart_disease
# 0       Fixed_Defect       Present
# 1  Reversable_Defect        Absent
# 2  Reversable_Defect       Present
# 3  Reversable_Defect        Absent
# 4       Fixed_Defect        Absent

# %%
heart.ST_slope
